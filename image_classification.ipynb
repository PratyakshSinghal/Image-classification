# %% [markdown]
# <a href="https://colab.research.google.com/github/PratyakshSinghal/Image-classification/blob/main/image_classification.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import tensorflow as tf
import os

# %%
tf.test.gpu_device_name()
# Out:
# '/device:GPU:0'

# %%
# Avoid OOM errors by setting GPU Memory Consumption Growth
gpus = tf.config.experimental.list_physical_devices('GPU')
for gpu in gpus:
    tf.config.experimental.set_memory_growth(gpu, True)

# %%
os.listdir('/content/drive/My Drive/face recognition Deep learning/data')
# Out:
# ['happy', 'sad']

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
drive.mount("/content/drive", force_remount=True)
# Out:
# Mounted at /content/drive

# %%
# Avois OOm errors by setting GPU memory consumption growth
gpus = tf.config.experimental.list_physical_devices('GPU')
for gpu in gpus:
    tf.config.experimental.set_memory_growth(gpu, True)

# %%
len(gpus)
# Out:
# 1

# %%
import cv2
import imghdr
import numpy as np
import matplotlib.pyplot as plt
data_dir = '/content/drive/My Drive/face recognition Deep learning/data'  # Path to the parent folder
# happy_dir = os.path.join(base_dir, 'happy')  # Path to the "happy" subfolder
# sad_dir = os.path.join(base_dir, 'sad')      # Path to the "sad" subfolder

# %% [markdown]
# ACCESS TO DATA

# %%
os.listdir(data_dir)
# Out:
# ['happy', 'sad']

# %% [markdown]
# ACCESS TO EVERY FOLDER IN DATASET (accessing the images of happy and sad people)

# %%
os.listdir(os.path.join(data_dir,'happy'))
# Out:
# ['image16.jpeg',
#  'image15.jpeg',
#  'image5.jpeg',
#  'image7.jpeg',
#  'image17.jpeg',
#  'image13.jpeg',
#  'image12.jpeg',
#  'image8.jpeg',
#  'images9.jpg',
#  'images.jpg',
#  'image30.jpeg',
#  'images22.jpg',
#  'image35.jpeg',
#  'image32.jpeg',
#  'images18.jpg',
#  'images10.jpg',
#  'images8.jpg',
#  'image28.jpeg',
#  'images4.jpg',
#  'image34.jpeg',
#  'images11.jpg',
#  'images2.jpg',
#  'images17.jpg',
#  'image33.jpeg',
#  'images19.jpg',
#  'image26.jpeg',
#  'images16.jpg',
#  'image27.jpeg',
#  'image31.jpeg',
#  'images51.jpg',
#  'images34.jpg',
#  'images30.jpg',
#  'images38.jpg',
#  'images33.jpg',
#  'images39.jpg',
#  'images36.jpg',
#  'images24.jpg',
#  'images47.jpg',
#  'images27.jpg',
#  'images41.jpg',
#  'images50.jpg',
#  'images44.jpg',
#  'images69.jpg',
#  'images86.jpg',
#  'images83.jpg',
#  'Overtly-Cheerful-Primer-Editorials-min.png',
#  'images73.jpg',
#  'images89.jpg',
#  'images80.jpg',
# ...

# %%
image_exts = ['jpeg', 'jpg', 'bmp', 'png']

# %%
image_exts[2]
# Out:
# 'bmp'

# %%
for image_class in os.listdir(data_dir):
    for image in os.listdir(os.path.join(data_dir, image_class)):
        image_path = os.path.join(data_dir, image_class, image)
        try:
            img = cv2.imread(image_path)
            tip = imghdr.what(image_path)
            if tip not in image_exts:
                print('Image not in ext list {}'.format(image_path))
                os.remove(image_path)
        except Exception as e:
            print('Issue with image {}'.format(image_path))
            # os.remove(image_path)
# Out:
# Issue with image /content/drive/My Drive/face recognition Deep learning/data/happy/.ipynb_checkpoints

# %%
for image_class in os.listdir(data_dir):
   for image in os.listdir(os.path.join(data_dir, image_class)):
    print(image)
# Out:
# image16.jpeg
# image15.jpeg
# image5.jpeg
# image7.jpeg
# image17.jpeg
# image13.jpeg
# image12.jpeg
# image8.jpeg
# images9.jpg
# images.jpg
# image30.jpeg
# images22.jpg
# image35.jpeg
# image32.jpeg
# images18.jpg
# images10.jpg
# images8.jpg
# image28.jpeg
# images4.jpg
# image34.jpeg
# images11.jpg
# images2.jpg
# images17.jpg
# image33.jpeg
# images19.jpg
# image26.jpeg
# images16.jpg
# image27.jpeg
# image31.jpeg
# images51.jpg
# images34.jpg
# images30.jpg
# images38.jpg
# images33.jpg
# images39.jpg
# images36.jpg
# images24.jpg
# images47.jpg
# images27.jpg
# images41.jpg
# images50.jpg
# images44.jpg
# images69.jpg
# images86.jpg
# images83.jpg
# Overtly-Cheerful-Primer-Editorials-min.png
# images73.jpg
# images89.jpg
# images80.jpg
# 1000_F_42220133_toAU6USGY9jVr2XJFLssfG00cSYIJ173.jpg
# images68.jpg
# images64.jpg
# images70.jpg
# 20150413185238-secrets-happy-entrepreneurs-woman-gratitude-rainbow-.jpeg
# happy-people-4316529-3613847.png
# ...

# %%
data_dir = '/content/drive/My Drive/face recognition Deep learning/data'

# %%
os.listdir(os.path.join(data_dir,'happy'  ))
# Out:
# ['image16.jpeg',
#  'image15.jpeg',
#  'image5.jpeg',
#  'image7.jpeg',
#  'image17.jpeg',
#  'image13.jpeg',
#  'image12.jpeg',
#  'image8.jpeg',
#  'images9.jpg',
#  'images.jpg',
#  'image30.jpeg',
#  'images22.jpg',
#  'image35.jpeg',
#  'image32.jpeg',
#  'images18.jpg',
#  'images10.jpg',
#  'images8.jpg',
#  'image28.jpeg',
#  'images4.jpg',
#  'image34.jpeg',
#  'images11.jpg',
#  'images2.jpg',
#  'images17.jpg',
#  'image33.jpeg',
#  'images19.jpg',
#  'image26.jpeg',
#  'images16.jpg',
#  'image27.jpeg',
#  'image31.jpeg',
#  'images51.jpg',
#  'images34.jpg',
#  'images30.jpg',
#  'images38.jpg',
#  'images33.jpg',
#  'images39.jpg',
#  'images36.jpg',
#  'images24.jpg',
#  'images47.jpg',
#  'images27.jpg',
#  'images41.jpg',
#  'images50.jpg',
#  'images44.jpg',
#  'images69.jpg',
#  'images86.jpg',
#  'images83.jpg',
#  'Overtly-Cheerful-Primer-Editorials-min.png',
#  'images73.jpg',
#  'images89.jpg',
#  'images80.jpg',
# ...

# %%
img = cv2.imread(os.path.join('data', 'happy','image14.img'))

# %%
for image_class in os.listdir(data_dir):
   for image in os.listdir(os.path.join(data_dir, image_class)):
    print(image)
# Out:
# image16.jpeg
# image15.jpeg
# image5.jpeg
# image7.jpeg
# image17.jpeg
# image13.jpeg
# image12.jpeg
# image8.jpeg
# images9.jpg
# images.jpg
# image30.jpeg
# images22.jpg
# image35.jpeg
# image32.jpeg
# images18.jpg
# images10.jpg
# images8.jpg
# image28.jpeg
# images4.jpg
# image34.jpeg
# images11.jpg
# images2.jpg
# images17.jpg
# image33.jpeg
# images19.jpg
# image26.jpeg
# images16.jpg
# image27.jpeg
# image31.jpeg
# images51.jpg
# images34.jpg
# images30.jpg
# images38.jpg
# images33.jpg
# images39.jpg
# images36.jpg
# images24.jpg
# images47.jpg
# images27.jpg
# images41.jpg
# images50.jpg
# images44.jpg
# images69.jpg
# images86.jpg
# images83.jpg
# Overtly-Cheerful-Primer-Editorials-min.png
# images73.jpg
# images89.jpg
# images80.jpg
# 1000_F_42220133_toAU6USGY9jVr2XJFLssfG00cSYIJ173.jpg
# images68.jpg
# images64.jpg
# images70.jpg
# 20150413185238-secrets-happy-entrepreneurs-woman-gratitude-rainbow-.jpeg
# happy-people-4316529-3613847.png
# ...

# %%
import numpy as np
from matplotlib import pyplot as plt

# %%
data = tf.keras.utils.image_dataset_from_directory('/content/drive/MyDrive/face recognition Deep learning/data')
# Out:
# Found 602 files belonging to 2 classes.

# %%
data_iterator = data.as_numpy_iterator()

# %%
batch = data_iterator.next()

# %%
fig, ax = plt.subplots(ncols=4, figsize=(20,20))
for idx, img in enumerate(batch[0][:4]):
    ax[idx].imshow(img.astype(int))
    ax[idx].title.set_text(batch[1][idx])

# %% [markdown]
# SCale Data

# %%
data = data.map(lambda x,y: (x/255, y))

# %%
data.as_numpy_iterator().next()
# Out:
# (array([[[[0.8585808 , 0.8607843 , 0.83811396],
#           [0.8471309 , 0.85026306, 0.82712835],
#           [0.8393143 , 0.83729225, 0.8167347 ],
#           ...,
#           [0.11590073, 0.18648897, 0.37472427],
#           [0.11718391, 0.1832577 , 0.37376732],
#           [0.12187859, 0.19329044, 0.3812512 ]],
#
#          [[0.87742037, 0.88134193, 0.85211396],
#           [0.8754505 , 0.87937206, 0.8501441 ],
#           [0.8616369 , 0.86555845, 0.84202904],
#           ...,
#           [0.11432029, 0.18490852, 0.37314382],
#           [0.11465203, 0.18888035, 0.37594974],
#           [0.11930147, 0.1867683 , 0.37671927]],
#
#          [[0.88592553, 0.8906743 , 0.85682017],
#           [0.8756381 , 0.88564384, 0.84943587],
#           [0.8685334 , 0.87245494, 0.8454329 ],
#           ...,
#           [0.10814951, 0.18121937, 0.36862746],
#           [0.11248205, 0.19235337, 0.37069282],
#           [0.11925887, 0.1854473 , 0.3758825 ]],
#
#          ...,
#
# ...

# %% [markdown]
# Split DATA

# %%
train_size = int(len(data)*.7)
val_size = int(len(data)*.2)
test_size = int(len(data)*.1)

# %%
train_size
# Out:
# 13

# %%
train = data.take(train_size)
val = data.skip(train_size).take(val_size)
test = data.skip(train_size+val_size).take(test_size)

# %% [markdown]
# Building deep learning model

# %%
train
# Out:
# <_TakeDataset element_spec=(TensorSpec(shape=(None, 256, 256, 3), dtype=tf.float32, name=None), TensorSpec(shape=(None,), dtype=tf.int32, name=None))>

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv2D, MaxPooling2D, Dense, Flatten, Dropout

# %%
model = Sequential()

# %%
model.add(Conv2D(16, (3,3), 1, activation='relu', input_shape=(256,256,3)))
model.add(MaxPooling2D())
model.add(Conv2D(32, (3,3), 1, activation='relu'))
model.add(MaxPooling2D())
model.add(Conv2D(16, (3,3), 1, activation='relu'))
model.add(MaxPooling2D())
model.add(Flatten())
model.add(Dense(256, activation='relu'))
model.add(Dense(1, activation='sigmoid'))

# %%
model.compile('adam', loss=tf.losses.BinaryCrossentropy(), metrics=['accuracy'])

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  conv2d (Conv2D)             (None, 254, 254, 16)      448
#
#  max_pooling2d (MaxPooling2  (None, 127, 127, 16)      0
#  D)
#
#  conv2d_1 (Conv2D)           (None, 125, 125, 32)      4640
#
#  max_pooling2d_1 (MaxPoolin  (None, 62, 62, 32)        0
#  g2D)
#
#  conv2d_2 (Conv2D)           (None, 60, 60, 16)        4624
#
#  max_pooling2d_2 (MaxPoolin  (None, 30, 30, 16)        0
#  g2D)
#
#  flatten (Flatten)           (None, 14400)             0
#
#  dense (Dense)               (None, 256)               3686656
#
#  dense_1 (Dense)             (None, 1)                 257
#
# ...
# Total params: 3696625 (14.10 MB)
# Trainable params: 3696625 (14.10 MB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %% [markdown]
# Train

# %%
logdir='logs'

# %%
tensorboard_callback = tf.keras.callbacks.TensorBoard(log_dir=logdir)
hist = model.fit(train, epochs=20, validation_data=val, callbacks=[tensorboard_callback])
# Out:
# Epoch 1/20
# 13/13 [==============================] - 15s 555ms/step - loss: 0.7263 - accuracy: 0.5168 - val_loss: 0.6714 - val_accuracy: 0.5833
# Epoch 2/20
# 13/13 [==============================] - 7s 417ms/step - loss: 0.6400 - accuracy: 0.6683 - val_loss: 0.6132 - val_accuracy: 0.6354
# Epoch 3/20
# 13/13 [==============================] - 8s 502ms/step - loss: 0.5925 - accuracy: 0.7404 - val_loss: 0.5294 - val_accuracy: 0.8229
# Epoch 4/20
# 13/13 [==============================] - 7s 411ms/step - loss: 0.4893 - accuracy: 0.7740 - val_loss: 0.4489 - val_accuracy: 0.7917
# Epoch 5/20
# 13/13 [==============================] - 8s 458ms/step - loss: 0.3601 - accuracy: 0.8750 - val_loss: 0.3162 - val_accuracy: 0.8542
# Epoch 6/20
# 13/13 [==============================] - 9s 570ms/step - loss: 0.3344 - accuracy: 0.8269 - val_loss: 0.2526 - val_accuracy: 0.9375
# Epoch 7/20
# ...

# %% [markdown]
# Plot performance

# %%
fig = plt.figure()
plt.plot(hist.history['loss'], color='teal', label='loss')
plt.plot(hist.history['val_loss'], color='orange', label='val_loss')
fig.suptitle('Loss', fontsize=20)
plt.legend(loc="upper left")
plt.show()

# %%
fig = plt.figure()
plt.plot(hist.history['accuracy'], color='teal', label='accuracy')
plt.plot(hist.history['val_accuracy'], color='orange', label='val_accuracy')
fig.suptitle('Accuracy', fontsize=20)
plt.legend(loc="upper left")
plt.show()

# %% [markdown]
# Evaluate

# %%
from tensorflow.keras.metrics import Precision, Recall, BinaryAccuracy
pre = Precision()
re = Recall()
acc = BinaryAccuracy()

# %%
for batch in test.as_numpy_iterator():
    X, y = batch
    yhat = model.predict(X)
    pre.update_state(y, yhat)
    re.update_state(y, yhat)
    acc.update_state(y, yhat)
# Out:
# 1/1 [==============================] - 0s 115ms/step

# %%
print(pre.result(), re.result(), acc.result())
# Out:
# tf.Tensor(1.0, shape=(), dtype=float32) tf.Tensor(1.0, shape=(), dtype=float32) tf.Tensor(1.0, shape=(), dtype=float32)

# %% [markdown]
# TEST

# %%
img_path = '/content/drive/MyDrive/face recognition Deep learning/data/happy/360_F_237330799_fynB7PDF8qXuq2qYTEKOa6E0Lt8Vbzv6.jpg'
img = cv2.imread(img_path)

# Check if the image was loaded correctly
if img is not None:
    # Convert the image from BGR to RGB
    img_rgb = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)

    # Display the image using Matplotlib
    plt.imshow(img_rgb)
    plt.axis('off')  # Hide axis
    plt.show()
else:
    print("Error: Image not found or unable to load.")

# %%
img = cv2.imread('/content/drive/MyDrive/face recognition Deep learning/data/happy/360_F_237330799_fynB7PDF8qXuq2qYTEKOa6E0Lt8Vbzv6.jpg')
plt.imshow(img)
plt.show()

# %%
resize = tf.image.resize(img, (256,256))
plt.imshow(resize.numpy().astype(int))
plt.show()

# %%
yhat = model.predict(np.expand_dims(resize/255, 0))
yhat
# Out:
# 1/1 [==============================] - 0s 247ms/step
# array([[0.08195571]], dtype=float32)

# %%
if yhat > 0.5:
    print(f'Predicted class is Sad')
else:
    print(f'Predicted class is Happy')
# Out:
# Predicted class is Happy

# %% [markdown]
# Save the Model

# %%
from tensorflow.keras.models import load_model
model.save(os.path.join('models','imageclassifier.h5'))
new_model = load_model('imageclassifier.h5')
new_model.predict(np.expand_dims(resize/255, 0))
array([[0.01972741]], dtype=float32)
